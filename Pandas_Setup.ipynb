# %% [markdown]
# <a href="https://colab.research.google.com/github/PeaceAndLongLife/pandas-workshop/blob/main/Pandas_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Load Git Repository {"form-width":"20%"}
clone_git = True # @param {"type":"boolean"}
if clone_git:
    # !git clone https://github.com/PeaceAndLongLife/pandas-workshop.git
